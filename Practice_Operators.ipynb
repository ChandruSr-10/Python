# %%
a=10 #hard coded

# %%
name=input("Enter your name") #inputs given will be considered as strings whether a number or a character
# Out:
# Enter your nameChandru

# %%
print(name)
# Out:
# Chandru

# %%
type(name)
# Out:
# str

# %%
otp=int(input("Eneter otp")) #to accept only the integer values we use this type casting
# Out:
# Eneter otp987

# %%
temp=int(input("Enter temp of your city"))
# Out:
# Enter temp of your city44

# %%
print(temp)
# Out:
# 44

# %%
type(temp)
# Out:
# int

# %%
temp1=float(input("Enter temp of your city"))
# Out:
# Enter temp of your city44.5

# %%
print(temp1)
# Out:
# 44.5

# %% [markdown]
# adding int(input or float(input is called type casting

# %%
type(temp1)
# Out:
# float

# %%
num_1=10
num_2=20

print(num_1+num_2)
print(num_1-num_2)
print(num_1/num_2) #single forward slash - float division
print(num_1//num_2) #double slash - integer division
print(num_1*num_2)
# Out:
# 30
# -10
# 0.5
# 0
# 200

# %%
a=2 #raise the power of 2 by 5 -- 2^5
print(a**5)
# Out:
# 32

# %%
b=7 #raise the power of 7 by 25 -- 7^25
print(b**25)
# Out:
# 1341068619663964900807

# %%
a=10
b=3

print(a%b) # %-Modulo
# a and b will be divided and the remained of the division will be in the output. will be displayes
# Out:
# 1

# %%
a=10
b=2

print(a%b)
# Out:
# 0

# %%
#comparision Opertaor
a=10
b=20
print(a<b)
print(a>b)
print(a>=b)
print(a<=b)
print(a==b) #equals
print(a!=b) #not equals
# Out:
# True
# False
# False
# True
# False
# True

# %%
#Logical operators - AND, OR, NOT

#AND
print(True and True)
print(True and False)
print(False and True)
print(False and False)

#OR
print(True or True)
print(True or False)
print(False or True)
print(False or False)

#Not
print(not False)
print(not True)
# Out:
# True
# False
# False
# False
# True
# True
# True
# False
# True
# False

# %%
print(not 5>7)
# Out:
# True
